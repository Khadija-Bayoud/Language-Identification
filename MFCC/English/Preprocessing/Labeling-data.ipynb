# %%
import os
import pandas as pd

# %%
df = pd.DataFrame(columns=["file path", "language"])

# %%
path = "/content/drive/MyDrive/Projet/Langues/MFCC/English/Preprocessing/Test"
lang = "English"

# %%
for filename in os.listdir(path + ("/F")) :
    file_path = path + ("/F/") + filename
    df = df.append({"file path": file_path, "language": lang}, ignore_index=True)

# %%
for filename in os.listdir(path + ("/H")) :
    file_path = path + ("/H/") + filename
    df = df.append({"file path": file_path, "language": lang}, ignore_index=True)

# %%
df.shape
# Out:
# (81, 2)

# %%
df.head()
# Out:
#                                            file path language
# 0  /content/drive/MyDrive/Projet/Langues/MFCC/Eng...  English
# 1  /content/drive/MyDrive/Projet/Langues/MFCC/Eng...  English
# 2  /content/drive/MyDrive/Projet/Langues/MFCC/Eng...  English
# 3  /content/drive/MyDrive/Projet/Langues/MFCC/Eng...  English
# 4  /content/drive/MyDrive/Projet/Langues/MFCC/Eng...  English

# %%
save_path = "/content/drive/MyDrive/Projet/Langues/MFCC/English/Preprocessing/"+lang+"_df.csv"
df.to_csv(save_path, index=False)
