# %%
pip install python_speech_features
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python_speech_features
#   Downloading python_speech_features-0.6.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: python_speech_features
#   Building wheel for python_speech_features (setup.py) ... done
#   Created wheel for python_speech_features: filename=python_speech_features-0.6-py3-none-any.whl size=5886 sha256=155caaf3d95cd70109c3d51c9133ae18765ee90ada1f0e0aeea025d1e157d72f
#   Stored in directory: /root/.cache/pip/wheels/5a/9e/68/30bad9462b3926c29e315df16b562216d12bdc215f4d240294
# Successfully built python_speech_features
# Installing collected packages: python_speech_features
# Successfully installed python_speech_features-0.6

# %%
from python_speech_features import mfcc
from sklearn.mixture import GaussianMixture
import scipy as sc
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')

# %%
dir = "/content/drive/MyDrive/Projet/Langues/Dataset/English"

# %%
folders_out = ["Train", "Test"]
folders_in = ["F", "H"]
mfcc_folder = "/content/drive/MyDrive/Projet/Langues/MFCC/English"

for folder_out in folders_out:
  for folder_in in folders_in:

    data_folder = dir + ("/") + folder_out + ("/") + folder_in
    audio_files = os.listdir(data_folder)
    audio_files = [filename for filename in audio_files if filename.endswith(('.wav'))]

    for audio_file in audio_files:
      
      basename = audio_file.split('.')[0]+("_mfcc")

      rate, data = sc.io.wavfile.read(os.path.join(data_folder, audio_file))
      mfcc_feat = mfcc(data, rate, nfft=2043)
      mfcc_feat_arr = np.asarray(mfcc_feat)

      path = mfcc_folder + ("/") + folder_out + ("/") + folder_in
      np.savetxt(path+("/")+basename+".txt", mfcc_feat_arr, delimiter=',')

# %% [markdown]
# **Silence Removal**

# %%
gmm = GaussianMixture(n_components=2, covariance_type='full')

for folder_out in folders_out:
  for folder_in in folders_in:

    data_folder = mfcc_folder + ("/") + folder_out + ("/") + folder_in
    mfcc_files = os.listdir(data_folder)
    mfcc_files = [filename for filename in mfcc_files if filename.endswith('txt')]

    for filename in mfcc_files :

      basename = filename.split('.')[0] + ("_no_silence")

      mfcc = np.loadtxt(os.path.join(data_folder, filename), delimiter=',')
      print("Avant : ", mfcc.shape)

      energies = np.sum(np.square(mfcc), axis=1)
      energies = energies.reshape(-1, 1)

      gmm.fit(energies)
      means = gmm.means_
      silence_component = np.argmin(means)
      silence_threshold = means[silence_component] - 2 * np.sqrt(gmm.covariances_[silence_component])
      
      non_silent_mask = energies > silence_threshold
      mfcc_no_silence = energies[non_silent_mask]
      print("Après : ", mfcc_no_silence.shape)

      path = mfcc_folder + ("/Preprocessing/") + folder_out + ("/") + folder_in
      np.savetxt(path+("/")+basename+".txt", mfcc_no_silence, delimiter=',')
# Out:
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (490,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (494,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (494,)
# Avant :  (499, 13)
# Après :  (492,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (13136, 13)
# Après :  (13128,)
# Avant :  (12120, 13)
# Après :  (11630,)
# Avant :  (2038, 13)
# Après :  (2037,)
# Avant :  (11599, 13)
# Après :  (11558,)
# Avant :  (11997, 13)
# Après :  (11904,)
# Avant :  (9254, 13)
# Après :  (9195,)
# Avant :  (12399, 13)
# Après :  (12399,)
# Avant :  (12599, 13)
# Après :  (12599,)
# Avant :  (7999, 13)
# Après :  (7999,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (493,)
# Avant :  (499, 13)
# Après :  (494,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (493,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (493,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (489,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (491,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (493,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (491,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (494,)
# Avant :  (499, 13)
# Après :  (492,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (494,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (490,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (493,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (493,)
# Avant :  (499, 13)
# Après :  (490,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (494,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (493,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (494,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (490,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (493,)
# Avant :  (499, 13)
# Après :  (492,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (494,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (492,)
# Avant :  (499, 13)
# Après :  (490,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (488,)
# Avant :  (499, 13)
# Après :  (492,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (493,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (494,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (482,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (491,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (493,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (493,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (486,)
# Avant :  (499, 13)
# Après :  (494,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (493,)
# Avant :  (499, 13)
# Après :  (494,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (1004, 13)
# Après :  (1004,)
# Avant :  (3230, 13)
# Après :  (3223,)
# Avant :  (5399, 13)
# Après :  (5399,)
# Avant :  (1034, 13)
# Après :  (1031,)
# Avant :  (11399, 13)
# Après :  (11397,)
# Avant :  (1497, 13)
# Après :  (1495,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (489,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (488,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (494,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (488,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (489,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (490,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (490,)
# Avant :  (499, 13)
# Après :  (494,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (493,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (493,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (493,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (493,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (496,)
# Avant :  (499, 13)
# Après :  (497,)
# Avant :  (499, 13)
# Après :  (499,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (498,)
# Avant :  (499, 13)
# Après :  (494,)
# Avant :  (499, 13)
# Après :  (495,)
# Avant :  (499, 13)
# Après :  (499,)
