# %%
import os 
import pandas as pd
import numpy as np
import joblib
from sklearn.mixture import GaussianMixture
from sklearn.metrics import confusion_matrix, mean_squared_error

# %%
gmm = joblib.load('/content/drive/MyDrive/Projet/Langues/GMM/Arabic/gmm_arabe64.gmm')
#labeled_data = pd.read_csv('/content/drive/MyDrive/Projet/Langues/MFCC/Arabic/Preprocessing/Arabic_df.csv')

# %%
languages = ['Arabic', 'English', 'French', 'Russian']
test_df = pd.DataFrame(columns=['file path', 'language'])

for lang in languages:
  path = '/content/drive/MyDrive/Projet/Langues/MFCC/'+lang+'/Preprocessing/'
  df = pd.read_csv(path + lang + '_df.csv')
  test_df = pd.concat([test_df, df], ignore_index=True)

print(test_df.shape)
print(test_df.loc[239])
# Out:
# (240, 2)
# file path    /content/drive/MyDrive/Projet/Langues/MFCC/Rus...
# language                                               Russian
# Name: 239, dtype: object

# %%
encoding = {'Arabic' : 0, 'English' : 1, 'French' : 2, 'Russian' : 3}

# %%
test_df['language'] = test_df['language'].map(encoding)

# %%
test_df.head(239)
# Out:
#                                              file path  language
# 0    /content/drive/MyDrive/Projet/Langues/MFCC/Ara...         0
# 1    /content/drive/MyDrive/Projet/Langues/MFCC/Ara...         0
# 2    /content/drive/MyDrive/Projet/Langues/MFCC/Ara...         0
# 3    /content/drive/MyDrive/Projet/Langues/MFCC/Ara...         0
# 4    /content/drive/MyDrive/Projet/Langues/MFCC/Ara...         0
# ..                                                 ...       ...
# 234  /content/drive/MyDrive/Projet/Langues/MFCC/Rus...         3
# 235  /content/drive/MyDrive/Projet/Langues/MFCC/Rus...         3
# 236  /content/drive/MyDrive/Projet/Langues/MFCC/Rus...         3
# 237  /content/drive/MyDrive/Projet/Langues/MFCC/Rus...         3
# 238  /content/drive/MyDrive/Projet/Langues/MFCC/Rus...         3
#
# [239 rows x 2 columns]

# %%
test_df['file path'][0]
# Out:
# '/content/drive/MyDrive/Projet/Langues/MFCC/Arabic/Preprocessing/Test/F/f4_mfcc_no_silence.txt'

# %%
 mfcc = np.loadtxt(test_df['file path'][0], delimiter=',').reshape(-1,1)
 print(mfcc.shape)
# Out:
# (8182, 1)

# %%
predictions = gmm.predict(mfcc)
predictions
# Out:
# array([28, 31, 17, ..., 45, 17,  1])

# %%
import matplotlib.pyplot as plt

# Plot the clusters
plt.scatter(mfcc[:, 0], mfcc[:, 1], c=predictions, s=40, cmap='viridis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-2cacdb850a45> in <cell line: 4>()
#       2
#       3 # Plot the clusters
# ----> 4 plt.scatter(mfcc[:, 0], mfcc[:, 1], c=predictions, s=40, cmap='viridis')
#       5 plt.show()
#
# IndexError: index 1 is out of bounds for axis 1 with size 1
